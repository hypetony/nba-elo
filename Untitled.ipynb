# %%
import pandas as pd

# 📌 Step 1: Load Dataset
file_path = "/users/tonyngo/Downloads/nba-forecasts/nba_elo.csv"  # Adjust the path if needed
df = pd.read_csv(file_path)

# 📌 Step 2: Explore the Data
print("Dataset Overview:")
print(df.head())  # Display the first few rows
print("\nSummary Statistics:")
print(df.describe())  # Summary statistics

# 📌 Step 3: Select Relevant Columns
df = df[['date', 'season', 'team1', 'team2', 'elo1_pre', 'elo2_pre', 'elo_prob1', 'elo_prob2', 'score1', 'score2']]

# 📌 Step 4: Convert 'date' to Datetime Format
df['date'] = pd.to_datetime(df['date'])

# 📌 Step 5: Basic Analysis
# Average scores for each team
avg_scores = df.groupby('team1')[['score1']].mean().rename(columns={'score1': 'avg_score'}).reset_index()

# Display the average scores
print("\nAverage Scores Per Team:")
print(avg_scores)

# 📌 Step 6: Save Cleaned Data (Optional)
output_file_path = "Downloads/cleaned_nba_elo.csv"  # Save directly to Downloads

# Save the cleaned data
df.to_csv(output_file_path, index=False)
print(f"\nCleaned data saved to: {output_file_path}")
# Out:
# Dataset Overview:
#          date  season  neutral playoff team1 team2  elo1_pre   elo2_pre  \
# 0  1946-11-01    1947        0     NaN   TRH   NYK    1300.0  1300.0000
# 1  1946-11-02    1947        0     NaN   PRO   BOS    1300.0  1300.0000
# 2  1946-11-02    1947        0     NaN   STB   PIT    1300.0  1300.0000
# 3  1946-11-02    1947        0     NaN   CHS   NYK    1300.0  1306.7233
# 4  1946-11-02    1947        0     NaN   DTF   WSC    1300.0  1300.0000
#
#    elo_prob1  elo_prob2  ...  carm-elo2_post  raptor1_pre  raptor2_pre  \
# 0   0.640065   0.359935  ...             NaN          NaN          NaN
# 1   0.640065   0.359935  ...             NaN          NaN          NaN
# 2   0.640065   0.359935  ...             NaN          NaN          NaN
# 3   0.631101   0.368899  ...             NaN          NaN          NaN
# 4   0.640065   0.359935  ...             NaN          NaN          NaN
#
#    raptor_prob1  raptor_prob2  score1  score2  quality  importance  \
# ...
